# %%
pip install librosa scikit-learn

# %%
import librosa
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
import librosa
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load audio and extract MFCC features
audio_path = 'Isaac Newton Was INSANE! Joe Rogan [TubeRipper.com] (1).wav'
audio, sr = librosa.load(audio_path, sr=None)
mfccs = librosa.feature.mfcc(y=audio, sr=sr)

# Standardize MFCC features
scaler = StandardScaler()
mfccs_scaled = scaler.fit_transform(mfccs.T)
kmeans = KMeans(n_clusters=2)  # Adjust based on the expected number of speakers
speaker_labels = kmeans.fit_predict(mfccs_scaled)

combined_segments = []
current_segment = {'speaker': speaker_labels[0], 'start': 0, 'end': 0}

for i in range(1, len(speaker_labels)):
    if speaker_labels[i] == current_segment['speaker']:
        current_segment['end'] = i
    else:
        combined_segments.append(current_segment)
        current_segment = {'speaker': speaker_labels[i], 'start': i, 'end': i}

# Add the last segment
combined_segments.append(current_segment)

transcripts = [...]

for i, segment in enumerate(combined_segments):
    speaker = segment['speaker']
    start_time = librosa.frames_to_time(segment['start'], sr=sr)
    end_time = librosa.frames_to_time(segment['end'], sr=sr)
    print(f"Segment {i + 1}: Speaker {speaker} (Time: {start_time:.2f}s - {end_time:.2f}s)")

    if i < len(transcripts):
        print("Transcript:", transcripts[i])
    else:
        print("No transcript available")

    print()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# No transcript available
#
# Segment 1248: Speaker 1 (Time: 156.89s - 157.14s)
# No transcript available
#
# Segment 1249: Speaker 0 (Time: 157.15s - 157.21s)
# No transcript available
#
# Segment 1250: Speaker 1 (Time: 157.22s - 157.53s)
# No transcript available
#
# Segment 1251: Speaker 0 (Time: 157.54s - 157.57s)
# No transcript available
#
# Segment 1252: Speaker 1 (Time: 157.58s - 157.75s)
# No transcript available
#
# Segment 1253: Speaker 0 (Time: 157.76s - 157.80s)
# No transcript available
#
# Segment 1254: Speaker 1 (Time: 157.81s - 157.83s)
# No transcript available
#
# Segment 1255: Speaker 0 (Time: 157.85s - 157.95s)
# No transcript available
#
# ...
